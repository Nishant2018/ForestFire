# %% [markdown]
# # Algerian Forest Fires Dataset Project EDA

# %% [markdown]
# # 1. UNDERSTANDING THE GIVEN TASK
# - Solve in ipynb:
#
# - Import the dataset. https://archive.ics.uci.edu/ml/datasets/Algerian+Forest+Fires+Dataset++#

# %% [markdown]
#  # 2. DATA COLLECTION AND UNDERSTANDING
# - I used a dataset on Algerian Forest Fires from UCI. The dataset contains a culmination of forest fire observations and data in two regions of Algeria: the Bejaia region and the Sidi Bel-Abbes region. The timeline of this dataset is from June 2012 to September 2012. In this project, we focused on whether certain weather features could predict forest fires in these regions using few Classification algorithms.
# - As per the Task given i choose regression problem to predict fire weather index

# %% [markdown]
# # 3 DATA EXPLORATION
# - In this step, we will apply Exploratory Data Analysis (EDA) to extract insights from the data set to know which features have contributed more in predicting Forest fire by performing Data Analysis using Pandas and Data visualization using Matplotlib & Seaborn.
# Below are tasks to be performed in EDA:
# M
# 1. Importing Libraries
#
# 2. Data Cleaning for EDA Report
#
# 3. Exploratory Data Analysis (EDA) on all Features

# %% [markdown]
# # 3.1 Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Create Dataframe and Read the dataset using Pandas
df = pd.read_csv('Algerian_forest_fires.csv',header = 1)
df.head()

#The header parameter is used to specify which row of the CSV file should be used as the column names for the DataFrame.
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5  \
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
[features for features in df.columns if df[features].isnull().sum()>1]
# Out:
# ['Classes  ']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.isnull().any()
# Out:
# day            False
# month           True
# year            True
# Temperature     True
#  RH             True
#  Ws             True
# Rain            True
# FFMC            True
# DMC             True
# DC              True
# ISI             True
# BUI             True
# FWI             True
# Classes         True
# dtype: bool

# %% [markdown]
# - Looks like all the features are identified as object but can be converted into numeric, if we remove rows which has strings.

# %% [markdown]
# # 3.4 Data Cleaning

# %%
# Coloumns which has null values
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN  \
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# The dataset is converted into two sets based on Region from 122th index, we can make a new column based on the Region
#
# 1 : "Bejaia Region Dataset"
#
# 2 : "Sidi-Bel Abbes Region Dataset"

# %% [markdown]
# # Add new column with region

# %%
# Set the 'Region' column to 1 for rows up to and including row 122
df.loc[:122,'Region']=1
# Set the 'Region' column to 2 for rows starting from row 123 onwards
df.loc[122:,'Region']=2

# Convert the 'Region' column to integer type
df[['Region']] = df[['Region']].astype(int)

# %%
df[['Region']]
# Out:
#      Region
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 241       2
# 242       2
# 243       2
# 244       2
# 245       2
#
# [246 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
# Remove null or na values rows
df =df.dropna().reset_index(drop=True)
df.shape
# Out:
# (244, 15)

# %%
# Column which has string
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
#
#      FWI  Classes    Region
# 122  FWI  Classes         2

# %% [markdown]
# # Null and other unwanted rows are removed

# %%
#remove 122th column
df= df.drop(122).reset_index(drop=True)

# %% [markdown]
# # Some column names were misspaced so we can fix it

# %%
# List out column names to check
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %% [markdown]
# # Looks like the values were misspaced so we can use str.strip() method

# %%
# Spaces were fixed in the column names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %% [markdown]
# # Changing the required columns as integer data type

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']
for i in objects:
    if i != 'Classes':
        df[i] = df[i].astype(float)

# %%
# Final datatypes check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    float64
#  1   month        243 non-null    float64
#  2   year         243 non-null    float64
#  3   Temperature  243 non-null    float64
#  4   RH           243 non-null    float64
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(13), int32(1), object(1)
# memory usage: 27.7+ KB

# %%
df.describe().T
# Out:
#              count         mean        std     min      25%     50%      75%
# day          243.0    15.761317   8.842552     1.0     8.00    16.0    23.00  \
# month        243.0     7.502058   1.114793     6.0     7.00     8.0     8.00
# year         243.0  2012.000000   0.000000  2012.0  2012.00  2012.0  2012.00
# Temperature  243.0    32.152263   3.628039    22.0    30.00    32.0    35.00
# RH           243.0    62.041152  14.828160    21.0    52.50    63.0    73.50
# Ws           243.0    15.493827   2.811385     6.0    14.00    15.0    17.00
# Rain         243.0     0.762963   2.003207     0.0     0.00     0.0     0.50
# FFMC         243.0    77.842387  14.349641    28.6    71.85    83.3    88.30
# DMC          243.0    14.680658  12.393040     0.7     5.80    11.3    20.80
# DC           243.0    49.430864  47.665606     6.9    12.35    33.1    69.10
# ISI          243.0     4.742387   4.154234     0.0     1.40     3.5     7.25
# BUI          243.0    16.690535  14.228421     1.1     6.00    12.4    22.65
# FWI          243.0     7.035391   7.440568     0.0     0.70     4.2    11.45
# Region       243.0     1.497942   0.501028     1.0     1.00     1.0     2.00
#
#                 max
# day            31.0
# month           9.0
# year         2012.0
# Temperature    42.0
# RH             90.0
# Ws             29.0
# Rain           16.8
# FFMC           96.0
# DMC            65.9
# DC            220.4
# ISI            19.0
# BUI            68.0
# FWI            31.1
# Region          2.0

# %% [markdown]
# # Data Cleaning in target variable

# %%
# Check Unique values of target variable
df.Classes.value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
# Strip mispaced values
df.Classes = df.Classes.str.strip()

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %% [markdown]
# # Region 1 (Bejaia Region)

# %%
df[:122]
# Out:
#       day  month    year  Temperature    RH    Ws  Rain  FFMC  DMC    DC  ISI
# 0     1.0    6.0  2012.0         29.0  57.0  18.0   0.0  65.7  3.4   7.6  1.3  \
# 1     2.0    6.0  2012.0         29.0  61.0  13.0   1.3  64.4  4.1   7.6  1.0
# 2     3.0    6.0  2012.0         26.0  82.0  22.0  13.1  47.1  2.5   7.1  0.3
# 3     4.0    6.0  2012.0         25.0  89.0  13.0   2.5  28.6  1.3   6.9  0.0
# 4     5.0    6.0  2012.0         27.0  77.0  16.0   0.0  64.8  3.0  14.2  1.2
# ..    ...    ...     ...          ...   ...   ...   ...   ...  ...   ...  ...
# 117  26.0    9.0  2012.0         31.0  54.0  11.0   0.0  82.0  6.0  16.3  2.5
# 118  27.0    9.0  2012.0         31.0  66.0  11.0   0.0  85.7  8.3  24.9  4.0
# 119  28.0    9.0  2012.0         32.0  47.0  14.0   0.7  77.5  7.1   8.8  1.8
# 120  29.0    9.0  2012.0         26.0  80.0  16.0   1.8  47.4  2.9   7.7  0.3
# 121  30.0    9.0  2012.0         25.0  78.0  14.0   1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI   Classes  Region
# 0    3.4  0.5  not fire       1
# 1    3.9  0.4  not fire       1
# 2    2.7  0.1  not fire       1
# 3    1.7  0.0  not fire       1
# 4    3.9  0.5  not fire       1
# ..   ...  ...       ...     ...
# 117  6.2  1.7  not fire       1
# 118  9.0  4.1      fire       1
# 119  6.8  0.9  not fire       1
# 120  3.0  0.1  not fire       1
# 121  2.4  0.1  not fire       1
#
# [122 rows x 15 columns]

# %% [markdown]
# # Region 2 (Sidi-Bel Abbes Region)

# %%
df[122:]
# Out:
#       day  month    year  Temperature    RH    Ws  Rain  FFMC   DMC    DC
# 122   1.0    6.0  2012.0         32.0  71.0  12.0   0.7  57.1   2.5   8.2  \
# 123   2.0    6.0  2012.0         30.0  73.0  13.0   4.0  55.7   2.7   7.8
# 124   3.0    6.0  2012.0         29.0  80.0  14.0   2.0  48.7   2.2   7.6
# 125   4.0    6.0  2012.0         30.0  64.0  14.0   0.0  79.4   5.2  15.4
# 126   5.0    6.0  2012.0         32.0  60.0  14.0   0.2  77.1   6.0  17.6
# ..    ...    ...     ...          ...   ...   ...   ...   ...   ...   ...
# 238  26.0    9.0  2012.0         30.0  65.0  14.0   0.0  85.4  16.0  44.5
# 239  27.0    9.0  2012.0         28.0  87.0  15.0   4.4  41.1   6.5   8.0
# 240  28.0    9.0  2012.0         27.0  87.0  29.0   0.5  45.9   3.5   7.9
# 241  29.0    9.0  2012.0         24.0  54.0  18.0   0.1  79.7   4.3  15.2
# 242  30.0    9.0  2012.0         24.0  64.0  15.0   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI   Classes  Region
# 122  0.6   2.8  0.2  not fire       2
# 123  0.6   2.9  0.2  not fire       2
# 124  0.3   2.6  0.1  not fire       2
# 125  2.2   5.6  1.0  not fire       2
# 126  1.8   6.5  0.9  not fire       2
# ..   ...   ...  ...       ...     ...
# 238  4.5  16.9  6.5      fire       2
# 239  0.1   6.2  0.0  not fire       2
# 240  0.4   3.4  0.2  not fire       2
# 241  1.7   5.1  0.7  not fire       2
# 242  1.2   4.8  0.5  not fire       2
#
# [121 rows x 15 columns]

# %%
df.to_csv('Algerian_forest_fires_dataset_CLEANED.csv', index=False)

# %% [markdown]
# # 3.5 Exploratory Data Analysis (EDA)

# %%
#Droping Year features
df1 = df.drop(['day','month','year'], axis=1)

# %%
# Encoding Not fire as 0 and Fire as 1
df1['Classes']= np.where(df1['Classes']== 'not fire',0,1)

# %%
# Check counts
df1.Classes.value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %% [markdown]
# # Visualization of Distribution

# %%
# PLot density plot for all features

# Set the plotting style to 'seaborn'
plt.style.use('seaborn')

# Create a histogram for each feature in the DataFrame 'df1'
# 'bins=50' specifies the number of bins in the histogram
# 'figsize=(20, 15)' determines the size of the entire figure
# 'ec='b'' sets the edge color of the bars to blue
df1.hist(bins=50, figsize=(20,15), ec = 'b')


# Display the plots
plt.show()

# %%
# Percentage for PieChart

# The `normalize=True` argument normalizes the counts to represent percentages.
percentage = df.Classes.value_counts(normalize=True)*100
percentage
# Out:
# Classes
# fire        56.378601
# not fire    43.621399
# Name: proportion, dtype: float64

# %% [markdown]
# # Charts

# %%
#plotting PieChart
classeslabels = ["FIRE", "NOT FIRE"]
plt.figure(figsize =(12, 7))

# 'autopct' parameter adds percentage labels to each slice
plt.pie(percentage,labels = classeslabels,autopct='%1.1f%%')
plt.title ("Pie Chart of Classes", fontsize = 15)
plt.show()

# %% [markdown]
# # Checking Multicollinearity

# %%
# Correlation chart
k = len(df1.columns) # Get the number of columns in the DataFrame df1
corr = df1.corr()  # Calculate the correlation matrix for df1

# Select the columns with the largest correlation to the 'Classes' column
cols = corr.nlargest(k, 'Classes')['Classes'].index


# Calculate the correlation coefficients between selected columns
cm = np.corrcoef(df1[cols].values.T)

sns.set(font_scale=1) # Set the font size for the heatmap

# Create a matplotlib figure and axis for the heatmap
f, ax = plt.subplots(figsize=(20, 13))

# Create a heatmap with correlation values and labels
hm = sns.heatmap(cm, annot=True, square=True, fmt='.2f', annot_kws={'size': 15}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# # Canadian Forest Fire Weather Index (FWI) System
# # This column can be considered for Regression problem

# %%
#Boxplot
ax = sns.boxplot(df['FWI'], color= 'red')

# %% [markdown]
# # Monthwise Fire Analysis

# %%
dftemp= df.loc[df['Region']== 1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')

# Create a countplot based on the 'month' and 'Classes' columns from the original DataFrame 'df'
# - 'x': Specifies the data for the x-axis, which is 'month'
# - 'hue': Colors the bars based on the 'Classes' column
# - 'data': Specifies the DataFrame to use for the plot, which is 'df'
# - 'ec': Sets the color of the edges of the bars to black
# - 'palette': Specifies the color palette to use for the plot, using the 'Set2' palette
sns.countplot(x='month',hue='Classes',data= df,ec = 'black', palette= 'Set2')
plt.title('Fire Analysis Month wise for Bejaia Region', fontsize=18, weight='bold')
plt.ylabel('Count', weight = 'bold')
plt.xlabel('Months', weight= 'bold')
plt.legend(loc='upper right')
# Customize the x-axis tick labels to display specific month names
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.grid(alpha = 0.5,axis = 'y')
plt.show()

# %%
dftemp= df.loc[df['Region']== 2]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data= df,ec = 'black', palette= 'Set2')
plt.title('Fire Analysis Month wise for Sidi-Bel Abbes Region', fontsize=18, weight='bold')
plt.ylabel('Count', weight = 'bold')
plt.xlabel('Months', weight= 'bold')
plt.legend(loc='upper right')
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.grid(alpha = 0.5,axis = 'y')
plt.show()

# %% [markdown]
# - Its observed that August and September had the most number of forest fires for both regions. And from the above plot of months, we can understand few things
#
# - Most of the fires happened in August and very high Fires happened in only 3 months - June, July and August.
#
# - Less Fires was on September

# %% [markdown]
# # 3.5 Exploratory Data Analysis (EDA) on all Features

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
def barchart(feature,xlabel):
    plt.figure(figsize=[14,8])
    by_feature =  df1.groupby([feature], as_index=False)['Classes'].sum()
    ax = sns.barplot(x=feature, y="Classes", data=by_feature[[feature,'Classes']], estimator=sum)
    ax.set(xlabel=xlabel, ylabel='Fire Count')

# %%
barchart('Temperature','Temperature Max in Celsius degrees')

# %%
barchart('Rain', 'Rain in mm')

# %% [markdown]
# # Fine Fuel Moisture Code (FFMC) index

# %%
barchart('Ws', 'Wind Speed in km/hr')

# %%
barchart('RH','Relative Humidity in %')

# %%
dftemp = df1.drop(['Classes', 'Region'], axis=1)
fig = plt.figure(figsize =(12, 6))
ax = dftemp.boxplot()
ax.set_title("Boxplot of Given Dataset")
plt.show()

# %%
dftemp = dftemp = df1.drop(['Region','Temperature','Rain','Ws','RH'], axis=1)
for feature in dftemp:
    sns.histplot(data = dftemp,x=feature, hue = 'Classes')
    plt.legend(labels=['Fire','Not Fire'])
    plt.title(feature)
    plt.show()

# %% [markdown]
# # REPORT
# Weather System Report
# - Temperature Highest Fire counts happened between 30-37 degree Celsius
# - Rain Highest Fire counts happened when there was no rain to very less rain ie. 0.0 to 0.3.
# - Wind Speed highest Fire count happened when the wind speed were between 13 to 19 Km/hr.
# - Relative Humidity highest fire count happened when the RH is between 50 to 80%.
# # FWI System Components Report
# # FWI (Canadian Forest Fire Weather Index)
#
# - Fine Fuel Moisture Code (FFMC) index which ranges between 28.6 to 92.5, here above 75 has higher chance of Forest fires.
#
# - Duff Moisture Code (DMC) index which ranges between 1.1 to 65.9, here 1.1-10 has lower chance of Forest fires whereas above 10-30 DMC has very high evidence of Forest fires in past.
#
# - Drought Code (DC) index which ranges between 7 to 220.4, here 0-25 is safe and has lower chance of Forest fires whereas range above 25 DC has higher chance of forest fires.
#
# - Initial Spread Index (ISI) index which ranges between 0 to 18, here 0-3 has lower Forest fires and above 3 ISI has higher chance of Forest fires.
#
# - Buildup Index (BUI) index which ranges between 1.1 to 68, here 1.1 to 10 has lower Forest fire chance and above 10 BUI has higher chance of forest fires.
#
# - Fire Weather Index (FWI) Index which ranges between 1 to 31.1, here 0-3 has lower chance of Forest fires and 3-25 FWI has higher chance of forest fires.
